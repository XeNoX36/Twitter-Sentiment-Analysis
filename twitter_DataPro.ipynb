# %%
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
print(stopwords.words("english"))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %% [markdown]
# *Data processing*

# %%
twit = pd.read_csv(r"c:\Users\USER\Documents\CODES\Python Work to Do\twitterData.csv", encoding = "ISO-8859-1")

# %%
# adding the column names
col_names = ["target", "id", "data", "flag", "user", "text"]
twit_data = twit.sample(frac=0.03125, random_state=42)
twit_data.columns = col_names
twit_data.shape
# Out:
# (50000, 6)

# %%
twit_data.head()
# Out:
#         target          id                          data      flag  \
# 541200       0  2200003313  Tue Jun 16 18:18:13 PDT 2009  NO_QUERY
# 750          0  1467998601  Mon Apr 06 23:11:18 PDT 2009  NO_QUERY
# 766711       0  2300049112  Tue Jun 23 13:40:12 PDT 2009  NO_QUERY
# 285055       0  1993474319  Mon Jun 01 10:26:09 PDT 2009  NO_QUERY
# 705995       0  2256551006  Sat Jun 20 12:56:51 PDT 2009  NO_QUERY
#
#                   user                                               text
# 541200   DEWGetMeTho77  @Nkluvr4eva My poor little dumpling  In Holmde...
# 750            Young_J  I'm off too bed. I gotta wake up hella early t...
# 766711   dougnawoschik  I havent been able to listen to it yet  My spe...
# 285055        thireven  now remembers why solving a relatively big equ...
# 705995  taracollins086                           Ate too much, feel sick

# %%
twit_data.isnull().sum()
# Out:
# target    0
# id        0
# data      0
# flag      0
# user      0
# text      0
# dtype: int64

# %%
# checking the distribution of target column
twit_data["target"].value_counts()
# Out:
# target
# 4    25014
# 0    24986
# Name: count, dtype: int64

# %%
# converting the targets to 0s and 1s
twit_data["target"] = twit_data["target"].replace(4, 1)
twit_data["target"].value_counts()
# Out:
# target
# 1    25014
# 0    24986
# Name: count, dtype: int64

# %% [markdown]
# *Stemming words to their root-word*

# %%
port_stem = PorterStemmer()

# %%
def stemming(content):
    stemmed_content = re.sub("[^a-zA-Z]", " ", content)
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words("english")]
    stemmed_content = " ".join(stemmed_content)

    return stemmed_content

# %%
twit_data["stemmed_content"] = twit_data["text"].apply(stemming)

# %%
twit_data.to_csv(r"c:\Users\USER\Documents\CODES\Python Work to Do\New_twitter_Data.csv", index=False)
